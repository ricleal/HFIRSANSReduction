# %%
#%matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt

plt.rcParams['image.cmap'] = 'viridis'
#plt.rcParams['figure.figsize'] = 20,10

import numpy as np

from sans.hfir.gpsans.data import Data
# Out:
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:257: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(monitor != time, "ERROR: monitor and time can not be both True or False.")

# %%
bc = Data("/Users/rhf/tmp/CG2_exp137_scan0067_0001.xml")
bc.plot(log=False)
# Out:
# 14:15:52 INFO    :  29: Using file /Users/rhf/tmp/CG2_exp137_scan0067_0001.xml.
# 14:15:52 INFO    :  31: Parsing: /Users/rhf/tmp/CG2_exp137_scan0067_0001.xml.
# <img src="data:image/png;base64,...">

# %%
bc.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
bc.df
# Out:
#        errors    i    j     name  values
# 0         0.0    0    0  b'main'       0
# 1         0.0    0    1  b'main'       0
# 2         0.0    0    2  b'main'       0
# 3         0.0    0    3  b'main'       0
# 4         0.0    0    4  b'main'       0
# 5         0.0    0    5  b'main'       0
# 6         0.0    0    6  b'main'       0
# 7         0.0    0    7  b'main'       0
# 8         0.0    0    8  b'main'       0
# 9         0.0    0    9  b'main'       0
# 10        0.0    0   10  b'main'       0
# 11        0.0    0   11  b'main'       0
# 12        0.0    0   12  b'main'       0
# 13        0.0    0   13  b'main'       0
# 14        0.0    0   14  b'main'       0
# 15        0.0    0   15  b'main'       0
# 16        0.0    0   16  b'main'       0
# 17        0.0    0   17  b'main'       0
# 18        0.0    0   18  b'main'       0
# 19        0.0    0   19  b'main'       0
# 20        0.0    0   20  b'main'       0
# 21        0.0    0   21  b'main'       0
# ...

# %%
bc.place_detectors_in_space()
bc.plot()
# Out:
# 14:15:52 INFO    : 123: Beam Center of Mass = (91.768689,121.004491) pixels.
# <img src="data:image/png;base64,...">
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:176: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[:,round(beam_center[0])] = values.max()
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:177: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[round(beam_center[1]),:] = values.max()

# %%
bc.meta
# Out:
# {'beam_center': [91.768689413439944, 121.00449093597678],
#  'counting_time': 120.0,
#  'monitor_counts': 3028637.0,
#  'sdd': 8.76,
#  'title': 'P1 T S8 8.7m4.75A4g',
#  'wavelength': 4.750739,
#  'wavelength_spread': 0.159892}

# %%
bc.df
# Out:
#        errors    i    j     name  values         x         y     z
# 0         0.0    0    0  b'main'       0 -0.504728  0.576181  8.76
# 1         0.0    0    1  b'main'       0 -0.499228  0.576181  8.76
# 2         0.0    0    2  b'main'       0 -0.493728  0.576181  8.76
# 3         0.0    0    3  b'main'       0 -0.488228  0.576181  8.76
# 4         0.0    0    4  b'main'       0 -0.482728  0.576181  8.76
# 5         0.0    0    5  b'main'       0 -0.477228  0.576181  8.76
# 6         0.0    0    6  b'main'       0 -0.471728  0.576181  8.76
# 7         0.0    0    7  b'main'       0 -0.466228  0.576181  8.76
# 8         0.0    0    8  b'main'       0 -0.460728  0.576181  8.76
# 9         0.0    0    9  b'main'       0 -0.455228  0.576181  8.76
# 10        0.0    0   10  b'main'       0 -0.449728  0.576181  8.76
# 11        0.0    0   11  b'main'       0 -0.444228  0.576181  8.76
# 12        0.0    0   12  b'main'       0 -0.438728  0.576181  8.76
# ...

# %%
data = Data("/Users/rhf/tmp/CG2_exp137_scan0063_0001.xml")
data.df
# Out:
# 14:15:53 INFO    :  29: Using file /Users/rhf/tmp/CG2_exp137_scan0063_0001.xml.
# 14:15:53 INFO    :  31: Parsing: /Users/rhf/tmp/CG2_exp137_scan0063_0001.xml.
#          errors    i    j     name  values
# 0      3.464102    0    0  b'main'      12
# 1      1.732051    0    1  b'main'       3
# 2      6.782330    0    2  b'main'      46
# 3      2.236068    0    3  b'main'       5
# 4      3.162278    0    4  b'main'      10
# 5      2.236068    0    5  b'main'       5
# 6      4.000000    0    6  b'main'      16
# 7      3.000000    0    7  b'main'       9
# 8      3.000000    0    8  b'main'       9
# 9      2.828427    0    9  b'main'       8
# 10     2.236068    0   10  b'main'       5
# 11     2.000000    0   11  b'main'       4
# 12     0.000000    0   12  b'main'       0
# 13     1.000000    0   13  b'main'       1
# 14     6.000000    0   14  b'main'      36
# 15     3.741657    0   15  b'main'      14
# 16     2.000000    0   16  b'main'       4
# ...

# %%
data.set_beam_center(bc)
data.df
# Out:
#          errors    i    j     name  values         x         y     z
# 0      3.464102    0    0  b'main'      12 -0.504728  0.576181  8.76
# 1      1.732051    0    1  b'main'       3 -0.499228  0.576181  8.76
# 2      6.782330    0    2  b'main'      46 -0.493728  0.576181  8.76
# 3      2.236068    0    3  b'main'       5 -0.488228  0.576181  8.76
# 4      3.162278    0    4  b'main'      10 -0.482728  0.576181  8.76
# 5      2.236068    0    5  b'main'       5 -0.477228  0.576181  8.76
# 6      4.000000    0    6  b'main'      16 -0.471728  0.576181  8.76
# 7      3.000000    0    7  b'main'       9 -0.466228  0.576181  8.76
# 8      3.000000    0    8  b'main'       9 -0.460728  0.576181  8.76
# 9      2.828427    0    9  b'main'       8 -0.455228  0.576181  8.76
# 10     2.236068    0   10  b'main'       5 -0.449728  0.576181  8.76
# 11     2.000000    0   11  b'main'       4 -0.444228  0.576181  8.76
# 12     0.000000    0   12  b'main'       0 -0.438728  0.576181  8.76
# ...

# %%
data.plot()
# Out:
# <img src="data:image/png;base64,...">
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:176: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[:,round(beam_center[0])] = values.max()
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:177: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[round(beam_center[1]),:] = values.max()

# %%
data.calculate_q_values()
data.df
# Out:
#          errors    i    j     name  values         x         y     z  \
# 0      3.464102    0    0  b'main'      12 -0.504728  0.576181  8.76
# 1      1.732051    0    1  b'main'       3 -0.499228  0.576181  8.76
# 2      6.782330    0    2  b'main'      46 -0.493728  0.576181  8.76
# 3      2.236068    0    3  b'main'       5 -0.488228  0.576181  8.76
# 4      3.162278    0    4  b'main'      10 -0.482728  0.576181  8.76
# 5      2.236068    0    5  b'main'       5 -0.477228  0.576181  8.76
# 6      4.000000    0    6  b'main'      16 -0.471728  0.576181  8.76
# 7      3.000000    0    7  b'main'       9 -0.466228  0.576181  8.76
# 8      3.000000    0    8  b'main'       9 -0.460728  0.576181  8.76
# 9      2.828427    0    9  b'main'       8 -0.455228  0.576181  8.76
# 10     2.236068    0   10  b'main'       5 -0.449728  0.576181  8.76
# 11     2.000000    0   11  b'main'       4 -0.444228  0.576181  8.76
# 12     0.000000    0   12  b'main'       0 -0.438728  0.576181  8.76
# ...

# %%
data.plot()
# Out:
# <img src="data:image/png;base64,...">
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:176: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[:,round(beam_center[0])] = values.max()
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:177: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[round(beam_center[1]),:] = values.max()

# %%
data.solid_angle_correction()
data.df
# Out:
#          errors    i    j     name     values         x         y     z  \
# 0      3.454230    0    0  b'main'  11.965805 -0.504728  0.576181  8.76
# 1      1.727161    0    1  b'main'   2.991531 -0.499228  0.576181  8.76
# 2      6.763363    0    2  b'main'  45.871359 -0.493728  0.576181  8.76
# 3      2.229873    0    3  b'main'   4.986148 -0.488228  0.576181  8.76
# 4      3.153598    0    4  b'main'   9.972553 -0.482728  0.576181  8.76
# 5      2.229988    0    5  b'main'   4.986404 -0.477228  0.576181  8.76
# 6      3.989224    0    6  b'main'  15.956897 -0.471728  0.576181  8.76
# 7      2.991993    0    7  b'main'   8.975979 -0.466228  0.576181  8.76
# 8      2.992067    0    8  b'main'   8.976200 -0.460728  0.576181  8.76
# 9      2.821016    0    9  b'main'   7.979039 -0.455228  0.576181  8.76
# 10     2.230263    0   10  b'main'   4.987020 -0.449728  0.576181  8.76
# 11     1.994855    0   11  b'main'   3.989711 -0.444228  0.576181  8.76
# ...

# %%
data.plot_iq(n_bins=100)
# Out:
# <img src="data:image/png;base64,...">

# %%
q = data.get_detector_2d(detector_name='main', values_name='q')
plt.figure()
plt.imshow(q)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
bg = Data("/Users/rhf/tmp/CG2_exp137_scan0069_0001.xml")
data -= bg
data.plot()
# Out:
# 14:15:54 INFO    :  29: Using file /Users/rhf/tmp/CG2_exp137_scan0069_0001.xml.
# 14:15:54 INFO    :  31: Parsing: /Users/rhf/tmp/CG2_exp137_scan0069_0001.xml.
# <img src="data:image/png;base64,...">
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:176: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[:,round(beam_center[0])] = values.max()
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:177: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[round(beam_center[1]),:] = values.max()

# %%
data.normalization(monitor=True)
data.plot()
# Out:
# <img src="data:image/png;base64,...">
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:176: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[:,round(beam_center[0])] = values.max()
# /Users/rhf/git/HFIRSANSReduction/src/sans/data.py:177: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   values[round(beam_center[1]),:] = values.max()

# %%
#data.df.to_csv("/tmp/test.csv")
data.df.to_hdf("/tmp/gpsans.hdf","data")
# Out:
# /usr/local/lib/python3.5/site-packages/pandas/core/generic.py:1101: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->bytes,key->block2_values] [items->['name']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
